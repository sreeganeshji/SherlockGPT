# %%
import torch

x = torch.rand((10,5,9)) # (B, T, num_embd * num_head_3)
x.shape
# Out:
# torch.Size([10, 5, 9])

# %%
count = 0
for y in x.split(3, 2):
    print(y.shape)
    count +=1

print(count)
# Out:
# torch.Size([10, 5, 3])
# torch.Size([10, 5, 3])
# torch.Size([10, 5, 3])
# 3

# %%
(k, q, v) = x.split(3,2)
